# %%
import pandas as pd
import plotly.express as px

df = pd.read_feather("adi_stats_zip5.feather")
df
# Out:
#       _state  _zip5  count   min   max   adi_mean  adi_median        std  \
# 0         AK  99501   2988   7.0  97.0  33.152276        36.0  18.076871
# 1         AK  99502   2745  11.0  43.0  24.122404        25.0   8.677508
# 2         AK  99503   2524  10.0  72.0  39.593502        41.0   8.925617
# 3         AK  99504   3420  19.0  98.0  36.341228        31.0  16.996213
# 4         AK  99505   1020  31.0  31.0  31.000000        31.0   0.000000
# ...      ...    ...    ...   ...   ...        ...         ...        ...
# 31525     WY  83124    267  38.0  74.0  48.921348        38.0  16.580783
# 31526     WY  83126    281  33.0  33.0  33.000000        33.0   0.000000
# 31527     WY  83127   1689  27.0  39.0  36.278863        39.0   4.083667
# 31528     WY  83128    892  23.0  44.0  42.233184        44.0   5.224854
# 31529     WY  83414    111   3.0  22.0   3.171171         3.0   1.803400
#
#             _lat        _lng  _census_total
# 0      61.219998 -149.857840          17603
# ...

# %%
px.scatter_3d(df, x='_lat', y='_lng', z='adi_median', size="_census_total", height=700)
